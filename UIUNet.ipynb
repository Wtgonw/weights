# %%
# !rm -rf /BasicIRSTD
# !git clone https://github.com/why-cq/BasicIRSTD

# %%
# 加载测试集代码
# !mkdir -p BasicIRSTD/datasets/WideIRSTD # 新建文件夹放测试数据
# !cp -r $DATA_PATH/* BasicIRSTD/datasets/WideIRSTD # 下载测试数据到/BasicIRSTD/datasets/WideIRSTD
# !cp -r BasicIRSTD/datasets/WideIRSTD/img_idx/test.txt BasicIRSTD/datasets/WideIRSTD/img_idx/test_WideIRSTD.txt 
# !cp -r BasicIRSTD/datasets/WideIRSTD/img_idx/test.txt BasicIRSTD/datasets/WideIRSTD/img_idx/train_WideIRSTD.txt

# %%
# %%bash
# # 往后的提交只需要修改地址和模型名称即可
# cd BasicIRSTD
# wget https://bohrium-api.dp.tech/file-dl/22bbba97461842b7a46a0e1d190632ae
# mv 22bbba97461842b7a46a0e1d190632ae UIUNet_100.pth.tar
# mkdir -p log/WideIRSTD/
# mv UIUNet_100.pth.tar log/WideIRSTD/

# %%
# !cd BasicIRSTD && python inference.py --model_names UIUNet --dataset_names WideIRSTD --pth_dirs WideIRSTD/UIUNet_100.pth.tar --threshold 0.3  --img_norm_cfg_mean 107.848 --img_norm_cfg_std 30.905

# %%
# %%bash
# original_dir=$PWD
# cd BasicIRSTD/results/WideIRSTD/
# cp -r UIUNet mask
# zip -r submission.zip mask/
# mv submission.zip $original_dir/
